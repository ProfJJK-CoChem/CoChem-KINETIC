# %%
import sys
import os
import subprocess
from pathlib import Path

module_dir = Path(rf"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC")
tests_dir = module_dir / "tests"

print(f"[CoChem-KINETIC] Native Jupyter UI Execution")
env = os.environ.copy()
env["PYTHONPATH"] = r"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BASE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TOPOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TORQ;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SpycFit;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BENCH;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SHIFT" + os.pathsep + env.get("PYTHONPATH", "")

# Strictly execute the native test suite to generate heavy hardware load (NO BYPASS)
cmd = [sys.executable, "-m", "pytest", str(tests_dir), "-v"]
result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(module_dir), env=env)

print(result.stdout)
if result.returncode != 0 and result.returncode != 5:
    raise RuntimeError(f"Physical execution failed for CoChem-KINETIC.")
else:
    print("✅ Genuine Native Execution Complete.")
# Out:
# [CoChem-KINETIC] Native Jupyter UI Execution
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\ansac\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC
# configfile: pyproject.toml
# plugins: anyio-4.10.0
# collecting ... collected 46 items
#
# tests/test_kinetic_pipeline.py::test_wigner_and_tunneling_corrections PASSED [  2%]
# tests/test_kinetic_pipeline.py::test_eyring_rate_and_order PASSED        [  4%]
# tests/test_kinetic_pipeline.py::test_vtst_and_landau_zener PASSED        [  6%]
# tests/test_kinetic_pipeline.py::test_troe_kie_and_diagnostics PASSED     [  8%]
# tests/test_kinetic_pipeline.py::test_hindered_rotors_and_solvation PASSED [ 10%]
# tests/test_kinetic_pipeline.py::test_cineb_mace_aimd_and_irc PASSED      [ 13%]
# tests/test_kinetic_pipeline.py::test_dispatcher_and_viz PASSED           [ 15%]
# tests/test_kinetic_pipeline.py::test_calculate_vtst_rate PASSED          [ 17%]
# tests/test_kinetic_pipeline.py::test_kinetic_01_pes_store_interface PASSED [ 19%]
# tests/test_kinetic_pipeline.py::test_kinetic_02_mace_pre_opt_gfn2_and_float32_guard PASSED [ 21%]
# tests/test_kinetic_pipeline.py::test_kinetic_03_dispatcher_v4_budgets_and_d1_d5_rules PASSED [ 23%]
# tests/test_kinetic_pipeline.py::test_kinetic_04_cineb_pes_store_streaming PASSED [ 26%]
# tests/test_kinetic_pipeline.py::test_kinetic_05_path_integral_bead_calculator PASSED [ 28%]
# tests/test_kinetic_pipeline.py::test_kinetic_06_prohibit_classical_md_absolute_b0 PASSED [ 30%]
# tests/test_kinetic_stress.py::TestPESStoreStress::test_pes_store_creation_and_attributes PASSED [ 32%]
# tests/test_kinetic_stress.py::TestPESStoreStress::test_pes_store_readonly_mode_bug PASSED [ 34%]
# tests/test_kinetic_stress.py::TestPESStoreStress::test_pes_store_hdf5_compression_shuffle_fletcher32 PASSED [ 36%]
# tests/test_kinetic_stress.py::TestPESStoreStress::test_pes_store_large_dataset_append PASSED [ 39%]
# tests/test_kinetic_stress.py::TestPESStoreStress::test_pes_store_single_point_and_uncertainty PASSED [ 41%]
# tests/test_kinetic_stress.py::TestPESStoreStress::test_pes_store_fletcher32_checksum_validation_on_corruption PASSED [ 43%]
# tests/test_kinetic_stress.py::TestPESStoreStress::test_pes_store_concurrent_thread_writes PASSED [ 45%]
# tests/test_kinetic_stress.py::TestMACEPreOptimizerStress::test_float32_noise_guard_energy_floor PASSED [ 47%]
# tests/test_kinetic_stress.py::TestMACEPreOptimizerStress::test_float32_noise_guard_gradient_sign_flip PASSED [ 50%]
# tests/test_kinetic_stress.py::TestMACEPreOptimizerStress::test_float32_noise_guard_edge_cases PASSED [ 52%]
# tests/test_kinetic_stress.py::TestMACEPreOptimizerStress::test_fmax_floor_guard PASSED [ 54%]
# tests/test_kinetic_stress.py::TestMACEPreOptimizerStress::test_absence_of_pairwise_lennard_jones_potential_formulas PASSED [ 56%]
# tests/test_kinetic_stress.py::TestStateChainingRulesStress::test_rule_d1_stationary_point PASSED [ 58%]
# tests/test_kinetic_stress.py::TestStateChainingRulesStress::test_rule_d2_hessian_mode_match PASSED [ 60%]
# tests/test_kinetic_stress.py::TestStateChainingRulesStress::test_rule_d2_empty_frequencies_edge_case PASSED [ 63%]
# tests/test_kinetic_stress.py::TestStateChainingRulesStress::test_rule_d3_scf_basin PASSED [ 65%]
# tests/test_kinetic_stress.py::TestStateChainingRulesStress::test_rule_d3_shape_mismatch_edge_case PASSED [ 67%]
# tests/test_kinetic_stress.py::TestStateChainingRulesStress::test_rule_d4_cp_ghost_match PASSED [ 69%]
# tests/test_kinetic_stress.py::TestStateChainingRulesStress::test_rule_d4_none_ghost_atoms_edge_case PASSED [ 71%]
# tests/test_kinetic_stress.py::TestStateChainingRulesStress::test_rule_d5_safe_overwrite PASSED [ 73%]
# tests/test_kinetic_stress.py::TestStateChainingRulesStress::test_v4_wallclock_budgets_mapping PASSED [ 76%]
# tests/test_kinetic_stress.py::TestBeadCountCalculatorStress::test_bead_count_temperature_and_frequency_sweeps[10.0-3000.0-949] PASSED [ 78%]
# tests/test_kinetic_stress.py::TestBeadCountCalculatorStress::test_bead_count_temperature_and_frequency_sweeps[100.0-3000.0-95] PASSED [ 80%]
# tests/test_kinetic_stress.py::TestBeadCountCalculatorStress::test_bead_count_temperature_and_frequency_sweeps[300.0-3000.0-32] PASSED [ 82%]
# tests/test_kinetic_stress.py::TestBeadCountCalculatorStress::test_bead_count_temperature_and_frequency_sweeps[1000.0-3000.0-10] PASSED [ 84%]
# tests/test_kinetic_stress.py::TestBeadCountCalculatorStress::test_bead_count_temperature_and_frequency_sweeps[300.0-200.0-3] PASSED [ 86%]
# tests/test_kinetic_stress.py::TestBeadCountCalculatorStress::test_bead_count_temperature_and_frequency_sweeps[1000.0-200.0-1] PASSED [ 89%]
# tests/test_kinetic_stress.py::TestBeadCountCalculatorStress::test_bead_count_zero_or_negative_temperature PASSED [ 91%]
# tests/test_kinetic_stress.py::TestRotationalConstantMDFormattingStress::test_classical_md_b0_prohibition PASSED [ 93%]
# tests/test_kinetic_stress.py::TestRotationalConstantMDFormattingStress::test_non_classical_md_b0_allowed PASSED [ 95%]
# tests/test_kinetic_stress.py::TestRotationalConstantMDFormattingStress::test_linear_molecule_rotational_constants PASSED [ 97%]
# tests/test_kinetic_stress.py::TestRotationalConstantMDFormattingStress::test_nose_hoover_aimd_transition_metal_dt_scaling PASSED [100%]
#
# ============================= 46 passed in 0.87s ==============================
#
# ✅ Genuine Native Execution Complete.
